# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from nba_api) (2023.11.17)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from nba_api) (1.26.4)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.31->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.31->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anthony thanpoovong\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.31->nba_api) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999')

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
career.get_json()

# dictionary
career.get_dict()
# Out:
# {'resource': 'playercareerstats',
#  'parameters': {'PerMode': 'Totals', 'PlayerID': 203999, 'LeagueID': None},
#  'resultSets': [{'name': 'SeasonTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '2015-16',
#      '00',
#      1610612743,
#      'DEN',
#      21.0,
#      80,
#      55,
#      1733.0,
#      307,
#      600,
#      0.512,
#      28,
#      84,
#      0.333,
#      154,
#      190,
#      0.811,
#      181,
#      379,
#      560,
#      189,
#      79,
#      50,
#      104,
#      208,
#      796],
#     [203999,
#      '2016-17',
#      '00',
#      1610612743,
#      'DEN',
#      22.0,
#      73,
#      59,
#      2038.0,
#      494,
#      854,
#      0.578,
#      45,
#      139,
#      0.324,
#      188,
#      228,
#      0.825,
#      212,
#      506,
#      718,
#      359,
#      61,
#      55,
#      171,
#      214,
#      1221],
#     [203999,
#      '2017-18',
#      '00',
#      1610612743,
#      'DEN',
#      23.0,
#      75,
#      73,
#      2443.0,
#      504,
#      1010,
#      0.499,
#      111,
#      280,
#      0.396,
#      266,
#      313,
#      0.85,
#      195,
#      608,
#      803,
#      458,
#      90,
#      61,
#      210,
#      212,
#      1385],
#     [203999,
#      '2018-19',
#      '00',
#      1610612743,
#      'DEN',
#      24.0,
#      80,
#      80,
#      2504.0,
#      616,
#      1206,
#      0.511,
#      83,
#      270,
#      0.307,
#      289,
#      352,
#      0.821,
#      228,
#      637,
#      865,
#      580,
#      108,
#      55,
#      248,
#      228,
#      1604],
#     [203999,
#      '2019-20',
#      '00',
#      1610612743,
#      'DEN',
#      25.0,
#      73,
#      73,
#      2335.0,
#      565,
#      1071,
#      0.528,
#      80,
#      255,
#      0.314,
#      246,
#      301,
#      0.817,
#      166,
#      545,
#      711,
#      512,
#      85,
#      44,
#      226,
#      222,
#      1456],
#     [203999,
#      '2020-21',
#      '00',
#      1610612743,
#      'DEN',
#      26.0,
#      72,
#      72,
#      2488.0,
#      732,
#      1293,
#      0.566,
#      92,
#      237,
#      0.388,
#      342,
#      394,
#      0.868,
#      205,
#      575,
#      780,
#      599,
#      95,
#      48,
#      222,
#      192,
#      1898],
#     [203999,
#      '2021-22',
#      '00',
#      1610612743,
#      'DEN',
#      27.0,
#      74,
#      74,
#      2476.0,
#      764,
#      1311,
#      0.583,
#      97,
#      288,
#      0.337,
#      379,
#      468,
#      0.81,
#      206,
#      813,
#      1019,
#      584,
#      109,
#      63,
#      281,
#      191,
#      2004],
#     [203999,
#      '2022-23',
#      '00',
#      1610612743,
#      'DEN',
#      28.0,
#      69,
#      69,
#      2323.0,
#      646,
#      1022,
#      0.632,
#      57,
#      149,
#      0.383,
#      341,
#      415,
#      0.822,
#      167,
#      650,
#      817,
#      678,
#      87,
#      47,
#      247,
#      174,
#      1690],
#     [203999,
#      '2023-24',
#      '00',
#      1610612743,
#      'DEN',
#      29.0,
#      79,
#      79,
#      2737.0,
#      822,
#      1411,
#      0.583,
#      83,
#      231,
#      0.359,
#      358,
#      438,
#      0.817,
#      223,
#      753,
#      976,
#      708,
#      108,
#      68,
#      237,
#      194,
#      2085]]},
#   {'name': 'CareerTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'LEAGUE_ID',
#     'Team_ID',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '00',
#      0,
#      675,
#      634,
#      21075.0,
#      5450,
#      9778,
#      0.557373,
#      676,
#      1933,
#      0.349715,
#      2563,
#      3099,
#      0.82704,
#      1783,
#      5466,
#      7249,
#      4667,
#      822,
#      491,
#      1946,
#      1835,
#      14139]]},
#   {'name': 'SeasonTotalsPostSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '2018-19',
#      '00',
#      1610612743,
#      'DEN',
#      24.0,
#      14,
#      14,
#      556.0,
#      132,
#      261,
#      0.506,
#      22,
#      56,
#      0.393,
#      66,
#      78,
#      0.846,
#      54,
#      128,
#      182,
#      118,
#      16,
#      13,
#      36,
#      54,
#      352],
#     [203999,
#      '2019-20',
#      '00',
#      1610612743,
#      'DEN',
#      25.0,
#      19,
#      19,
#      694.0,
#      178,
#      343,
#      0.519,
#      42,
#      98,
#      0.429,
#      66,
#      79,
#      0.835,
#      37,
#      150,
#      187,
#      109,
#      20,
#      15,
#      62,
#      68,
#      464],
#     [203999,
#      '2020-21',
#      '00',
#      1610612743,
#      'DEN',
#      26.0,
#      10,
#      10,
#      345.0,
#      116,
#      228,
#      0.509,
#      20,
#      53,
#      0.377,
#      46,
#      55,
#      0.836,
#      37,
#      79,
#      116,
#      50,
#      6,
#      9,
#      24,
#      23,
#      298],
#     [203999,
#      '2021-22',
#      '00',
#      1610612743,
#      'DEN',
#      27.0,
#      5,
#      5,
#      171.0,
#      61,
#      106,
#      0.575,
#      5,
#      18,
#      0.278,
#      28,
#      33,
#      0.848,
#      17,
#      49,
#      66,
#      29,
#      8,
#      5,
#      24,
#      20,
#      155],
#     [203999,
#      '2022-23',
#      '00',
#      1610612743,
#      'DEN',
#      28.0,
#      20,
#      20,
#      789.0,
#      227,
#      414,
#      0.548,
#      35,
#      76,
#      0.461,
#      111,
#      139,
#      0.799,
#      69,
#      200,
#      269,
#      190,
#      21,
#      20,
#      70,
#      69,
#      600],
#     [203999,
#      '2023-24',
#      '00',
#      1610612743,
#      'DEN',
#      29.0,
#      12,
#      12,
#      482.0,
#      133,
#      244,
#      0.545,
#      14,
#      53,
#      0.264,
#      64,
#      71,
#      0.901,
#      43,
#      118,
#      161,
#      104,
#      17,
#      8,
#      40,
#      32,
#      344]]},
#   {'name': 'CareerTotalsPostSeason',
#    'headers': ['PLAYER_ID',
#     'LEAGUE_ID',
#     'Team_ID',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '00',
#      0,
#      80,
#      80,
#      3038.0,
#      847,
#      1596,
#      0.530701,
#      138,
#      354,
#      0.38983,
#      381,
#      455,
#      0.837362,
#      257,
#      724,
#      981,
#      600,
#      88,
#      70,
#      256,
#      266,
#      2213]]},
#   {'name': 'SeasonTotalsAllStarSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '2018-19',
#      '00',
#      1610616833,
#      'GNS',
#      24.0,
#      1,
#      0,
#      13.0,
#      3,
#      4,
#      0.75,
#      0,
#      0,
#      0.0,
#      0,
#      0,
#      0.0,
#      3,
#      6,
#      9,
#      0,
#      0,
#      0,
#      1,
#      1,
#      6],
#     [203999,
#      '2019-20',
#      '00',
#      1610616834,
#      'LBN',
#      25.0,
#      1,
#      0,
#      12.0,
#      2,
#      4,
#      0.5,
#      1,
#      3,
#      0.333,
#      0,
#      0,
#      0.0,
#      0,
#      2,
#      2,
#      1,
#      1,
#      0,
#      0,
#      1,
#      5],
#     [203999,
#      '2020-21',
#      '00',
#      1610616834,
#      'LBN',
#      26.0,
#      1,
#      1,
#      19.0,
#      3,
#      4,
#      0.75,
#      0,
#      0,
#      0.0,
#      0,
#      0,
#      0.0,
#      0,
#      7,
#      7,
#      5,
#      0,
#      1,
#      2,
#      1,
#      6],
#     [203999,
#      '2021-22',
#      '00',
#      1610616834,
#      'LBN',
#      27.0,
#      1,
#      1,
#      21.0,
#      4,
#      5,
#      0.8,
#      2,
#      3,
#      0.667,
#      0,
#      0,
#      0.0,
#      3,
#      6,
#      9,
#      8,
#      1,
#      0,
#      1,
#      0,
#      10],
#     [203999,
#      '2022-23',
#      '00',
#      1610616834,
#      'LBN',
#      28.0,
#      1,
#      1,
#      20.0,
#      2,
#      4,
#      0.5,
#      0,
#      1,
#      0.0,
#      0,
#      0,
#      0.0,
#      3,
#      2,
#      5,
#      6,
#      2,
#      0,
#      2,
#      0,
#      4],
#     [203999,
#      '2023-24',
#      '00',
#      1610616834,
#      'WST',
#      29.0,
#      1,
#      1,
#      23.0,
#      6,
#      8,
#      0.75,
#      1,
#      1,
#      1.0,
#      0,
#      0,
#      0.0,
#      3,
#      1,
#      4,
#      9,
#      2,
#      0,
#      1,
#      1,
#      13]]},
#   {'name': 'CareerTotalsAllStarSeason',
#    'headers': ['PLAYER_ID',
#     'LEAGUE_ID',
#     'Team_ID',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '00',
#      0,
#      6,
#      4,
#      109.0,
#      20,
#      29,
#      0.689655,
#      4,
#      8,
#      0.5,
#      0,
#      0,
#      0.0,
#      12,
#      24,
#      36,
#      29,
#      6,
#      1,
#      7,
#      4,
#      44]]},
#   {'name': 'SeasonTotalsCollegeSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'ORGANIZATION_ID',
#     'SCHOOL_NAME',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': []},
#   {'name': 'CareerTotalsCollegeSeason',
#    'headers': ['PLAYER_ID',
#     'LEAGUE_ID',
#     'ORGANIZATION_ID',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': []},
#   {'name': 'SeasonTotalsShowcaseSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': []},
#   {'name': 'CareerTotalsShowcaseSeason',
#    'headers': ['PLAYER_ID',
#     'LEAGUE_ID',
#     'Team_ID',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': []},
#   {'name': 'SeasonRankingsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'RANK_MIN',
#     'RANK_FGM',
#     'RANK_FGA',
#     'RANK_FG_PCT',
#     'RANK_FG3M',
#     'RANK_FG3A',
#     'RANK_FG3_PCT',
#     'RANK_FTM',
#     'RANK_FTA',
#     'RANK_FT_PCT',
#     'RANK_OREB',
#     'RANK_DREB',
#     'RANK_REB',
#     'RANK_AST',
#     'RANK_STL',
#     'RANK_BLK',
#     'RANK_TOV',
#     'RANK_PTS',
#     'RANK_EFF'],
#    'rowSet': [[203999,
#      '2015-16',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      152,
#      112,
#      135,
#      18,
#      223,
#      227,
#      None,
#      90,
#      104,
#      58,
#      24,
#      45,
#      38,
#      82,
#      61,
#      68,
#      115,
#      120,
#      50],
#     [203999,
#      '2016-17',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      108,
#      34,
#      68,
#      6,
#      192,
#      188,
#      None,
#      61,
#      65,
#      46,
#      12,
#      17,
#      13,
#      31,
#      106,
#      51,
#      32,
#      41,
#      17],
#     [203999,
#      '2017-18',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      40,
#      29,
#      36,
#      29,
#      88,
#      99,
#      35,
#      25,
#      30,
#      26,
#      10,
#      8,
#      7,
#      12,
#      38,
#      47,
#      16,
#      26,
#      8],
#     [203999,
#      '2018-19',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      34,
#      19,
#      25,
#      31,
#      128,
#      107,
#      128,
#      28,
#      34,
#      52,
#      10,
#      9,
#      8,
#      6,
#      19,
#      53,
#      9,
#      22,
#      4],
#     [203999,
#      '2019-20',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      11,
#      11,
#      21,
#      19,
#      127,
#      102,
#      142,
#      29,
#      30,
#      56,
#      14,
#      8,
#      8,
#      6,
#      25,
#      63,
#      8,
#      18,
#      3],
#     [203999,
#      '2020-21',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      3,
#      1,
#      8,
#      14,
#      117,
#      132,
#      75,
#      12,
#      14,
#      26,
#      8,
#      7,
#      5,
#      3,
#      11,
#      55,
#      5,
#      3,
#      1],
#     [203999,
#      '2021-22',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      18,
#      2,
#      8,
#      8,
#      121,
#      110,
#      120,
#      9,
#      8,
#      63,
#      13,
#      1,
#      1,
#      6,
#      10,
#      34,
#      5,
#      5,
#      1],
#     [203999,
#      '2022-23',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      47,
#      13,
#      47,
#      8,
#      208,
#      220,
#      None,
#      23,
#      22,
#      58,
#      25,
#      3,
#      3,
#      2,
#      28,
#      62,
#      5,
#      17,
#      1],
#     [203999,
#      '2023-24',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      9,
#      2,
#      11,
#      10,
#      156,
#      158,
#      114,
#      15,
#      15,
#      60,
#      9,
#      2,
#      3,
#      2,
#      8,
#      32,
#      9,
#      5,
#      1]]},
#   {'name': 'SeasonRankingsPostSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'RANK_MIN',
#     'RANK_FGM',
#     'RANK_FGA',
#     'RANK_FG_PCT',
#     'RANK_FG3M',
#     'RANK_FG3A',
#     'RANK_FG3_PCT',
#     'RANK_FTM',
#     'RANK_FTA',
#     'RANK_FT_PCT',
#     'RANK_OREB',
#     'RANK_DREB',
#     'RANK_REB',
#     'RANK_AST',
#     'RANK_STL',
#     'RANK_BLK',
#     'RANK_TOV',
#     'RANK_PTS',
#     'RANK_EFF'],
#    'rowSet': [[203999,
#      '2018-19',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      13,
#      7,
#      9,
#      14,
#      20,
#      28,
#      29,
#      8,
#      10,
#      27,
#      1,
#      6,
#      4,
#      4,
#      18,
#      14,
#      12,
#      10,
#      4],
#     [203999,
#      '2019-20',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      6,
#      4,
#      4,
#      12,
#      10,
#      16,
#      19,
#      10,
#      10,
#      31,
#      4,
#      2,
#      4,
#      4,
#      11,
#      8,
#      2,
#      5,
#      3],
#     [203999,
#      '2020-21',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      37,
#      13,
#      13,
#      18,
#      36,
#      38,
#      44,
#      14,
#      15,
#      30,
#      8,
#      16,
#      12,
#      20,
#      58,
#      25,
#      19,
#      14,
#      13],
#     [203999,
#      '2021-22',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      85,
#      32,
#      44,
#      7,
#      97,
#      90,
#      79,
#      32,
#      34,
#      21,
#      26,
#      38,
#      35,
#      44,
#      51,
#      53,
#      27,
#      38,
#      37],
#     [203999,
#      '2022-23',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      5,
#      1,
#      2,
#      11,
#      14,
#      25,
#      12,
#      3,
#      2,
#      32,
#      1,
#      1,
#      1,
#      1,
#      8,
#      6,
#      1,
#      1,
#      1],
#     [203999,
#      '2023-24',
#      '00',
#      1610612743,
#      'DEN',
#      'NR',
#      'NR',
#      'NR',
#      21,
#      8,
#      9,
#      10,
#      46,
#      36,
#      80,
#      7,
#      10,
#      9,
#      3,
#      3,
#      3,
#      5,
#      10,
#      31,
#      6,
#      8,
#      3]]}]}

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2024-07-11 01:00:07.07',
#   'code': 200},
#  'scoreboard': {'gameDate': '2024-07-10',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': []}}

# %%
import pandas as pd

# Raw URL to the CSV file
path = "https://raw.githubusercontent.com/anthonythanpoovong/NBA-Sports-Betting-Analysis-App/dataset/nba_games.csv"
df = pd.read_csv(path)

# Display the DataFrame
print(df.describe())
print(df)
# Out:
#          Unnamed: 0            mp          mp.1            fg           fga  \
# count  17772.000000  17772.000000  17772.000000  17772.000000  17772.000000
# mean    8885.500000    241.564258    241.564258     39.954817     87.020538
# std     5130.478828      7.002952      7.002952      5.225686      7.233960
# min        0.000000    240.000000    240.000000     19.000000     60.000000
# 25%     4442.750000    240.000000    240.000000     36.000000     82.000000
# 50%     8885.500000    240.000000    240.000000     40.000000     87.000000
# 75%    13328.250000    240.000000    240.000000     43.000000     92.000000
# max    17771.000000    340.000000    340.000000     63.000000    128.000000
#
#                 fg%            3p           3pa           3p%            ft  \
# count  17772.000000  17772.000000  17772.000000  17772.000000  17772.000000
# mean       0.460049     11.022901     30.800923      0.356935     17.415710
# std        0.054656      3.961903      7.905325      0.089744      5.969888
# min        0.269000      0.000000      4.000000      0.000000      1.000000
# 25%        0.422000      8.000000     25.000000      0.297000     13.000000
# 50%        0.459000     11.000000     31.000000      0.355000     17.000000
# 75%        0.495000     14.000000     36.000000      0.417000     21.000000
# max        0.687000     29.000000     70.000000      0.842000     44.000000
#
#        ...  ast%_max_opp  stl%_max_opp  blk%_max_opp  tov%_max_opp  \
# count  ...  17772.000000  17772.000000  17772.000000  17772.000000
# mean   ...     42.718473      5.937964      9.013302     40.079811
# std    ...     14.801285      4.493377      6.725743     21.216193
# min    ...     12.800000      0.000000      0.000000      4.600000
# 25%    ...     32.700000      3.800000      5.200000     25.500000
# 50%    ...     40.000000      5.000000      7.500000     33.300000
# 75%    ...     48.900000      6.700000     10.800000     50.000000
# max    ...    100.000000    100.000000    100.000000    100.000000
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp     total_opp      home_opp  \
# count  17772.000000  17772.000000  17772.000000  17772.000000  17772.000000
# mean      34.864979    178.187430    118.660758    108.348244      0.500000
# std        8.505948     40.809205     11.087727     12.786684      0.500014
# min       22.100000     89.000000     77.000000     64.000000      0.000000
# 25%       30.000000    148.000000    111.000000    100.000000      0.000000
# 50%       33.000000    167.000000    119.000000    108.000000      0.500000
# 75%       37.200000    202.000000    126.000000    117.000000      1.000000
# max      100.000000    300.000000    162.000000    168.000000      1.000000
#
#              season
# count  17772.000000
# mean    2018.952284
# std        2.015800
# min     2016.000000
# 25%     2017.000000
# 50%     2019.000000
# 75%     2021.000000
# max     2022.000000
#
# [8 rows x 147 columns]
#        Unnamed: 0     mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft  \
# 0               0  240.0  240.0  39.0   81.0  0.481   6.0  20.0  0.300  14.0
# 1               1  240.0  240.0  36.0  100.0  0.360   7.0  31.0  0.226  16.0
# 2               2  240.0  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0
# 3               3  240.0  240.0  41.0   89.0  0.461   8.0  21.0  0.381  17.0
# 4               4  240.0  240.0  27.0   86.0  0.314   6.0  26.0  0.231  15.0
# ...           ...    ...    ...   ...    ...    ...   ...   ...    ...   ...
# 17767       17767  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0
# 17768       17768  240.0  240.0  37.0   74.0  0.500  13.0  25.0  0.520  26.0
# 17769       17769  240.0  240.0  42.0   89.0  0.472  14.0  33.0  0.424  10.0
# 17770       17770  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0
# 17771       17771  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0
#
#        ...  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0      ...          22.8          29.0         178.0         111.0       DAL
# 1      ...          50.0          32.6         152.0         111.0       ATL
# 2      ...          20.0          30.9         148.0         116.0       SAS
# 3      ...          28.6          30.9         138.0         118.0       MIN
# 4      ...          16.8          30.9         157.0          90.0       MEM
# ...    ...           ...           ...           ...           ...       ...
# 17767  ...          34.2          33.7         160.0         118.0       OKC
# 17768  ...          25.0          30.0         139.0         129.0       ORL
# 17769  ...          25.6          29.9         175.0         126.0       LAC
# 17770  ...          27.7          27.1         150.0         126.0       MIA
# 17771  ...          51.5          36.2         141.0         114.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0             95         1    2016  2015-12-09   True
# 1             98         0    2016  2015-12-09  False
# 2            107         1    2018  2017-10-18  False
# 3             99         0    2018  2017-10-18   True
# 4             92         1    2021  2021-04-30  False
# ...          ...       ...     ...         ...    ...
# 17767         92         0    2019  2018-10-19   True
# 17768        108         1    2017  2016-12-14   True
# 17769        113         0    2017  2016-12-14  False
# 17770        106         1    2020  2020-09-19   True
# 17771        117         0    2020  2020-09-19  False
#
# [17772 rows x 151 columns]

# %% [markdown]
# Mp = minutes played
#
# fg =
#
# fga =
#
# 3p =
#
# 3pa =

# %%
df = df.sort_values("date")
df = df.reset_index(drop = True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]
df
# Out:
#        Unnamed: 0     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  \
# 0           16086  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0
# 1           16904  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0
# 2           16905  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0
# 3           16087  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0
# 4            1225  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0
# ...           ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 17767         973  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0
# 17768       11533  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0
# 17769       11532  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0
# 17770        7477  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0
# 17771        7476  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0
#
#        ...  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0      ...          69.4          43.7         206.0         104.0       GSW
# 1      ...          53.2          34.6         162.0         104.0       CHI
# 2      ...          30.4          29.0         138.0         105.0       CLE
# 3      ...          37.5          38.9         201.0         120.0       NOP
# 4      ...          33.3          23.6         132.0         104.0       DET
# ...    ...           ...           ...           ...           ...       ...
# 17767  ...          42.9          36.3         133.0         112.0       GSW
# 17768  ...          45.0          94.4         300.0         112.0       BOS
# 17769  ...          33.3          36.2         222.0         107.0       GSW
# 17770  ...          33.3          31.5         186.0         111.0       GSW
# 17771  ...         100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0            111         1    2016  2015-10-27  False
# 1             97         1    2016  2015-10-27  False
# 2             95         0    2016  2015-10-27   True
# 3             95         0    2016  2015-10-27   True
# 4            106         0    2016  2015-10-27  False
# ...          ...       ...     ...         ...    ...
# 17767        107         0    2022  2022-06-10  False
# 17768         94         0    2022  2022-06-13   True
# 17769        104         1    2022  2022-06-13  False
# 17770        103         0    2022  2022-06-16  False
# 17771         90         1    2022  2022-06-16   True
#
# [17772 rows x 148 columns]

# %%
def add_target(team):
  team["target"] = team["won"].shift(-1)
  return team

df = df.groupby("team", group_keys = False).apply(add_target)
# Out:
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\586859865.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("team", group_keys = False).apply(add_target)

# %%
df
# Out:
#        Unnamed: 0     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  \
# 0           16086  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0
# 1           16904  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0
# 2           16905  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0
# 3           16087  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0
# 4            1225  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0
# ...           ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 17767         973  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0
# 17768       11533  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0
# 17769       11532  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0
# 17770        7477  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0
# 17771        7476  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          43.7         206.0         104.0       GSW        111
# 1      ...          34.6         162.0         104.0       CHI         97
# 2      ...          29.0         138.0         105.0       CLE         95
# 3      ...          38.9         201.0         120.0       NOP         95
# 4      ...          23.6         132.0         104.0       DET        106
# ...    ...           ...           ...           ...       ...        ...
# 17767  ...          36.3         133.0         112.0       GSW        107
# 17768  ...          94.4         300.0         112.0       BOS         94
# 17769  ...          36.2         222.0         107.0       GSW        104
# 17770  ...          31.5         186.0         111.0       GSW        103
# 17771  ...          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False   False
# 1             1    2016  2015-10-27  False    True
# 2             0    2016  2015-10-27   True    True
# 3             0    2016  2015-10-27   True    True
# 4             0    2016  2015-10-27  False    True
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False   False
# 17768         0    2022  2022-06-13   True    True
# 17769         1    2022  2022-06-13  False   False
# 17770         0    2022  2022-06-16  False     NaN
# 17771         1    2022  2022-06-16   True     NaN
#
# [17772 rows x 149 columns]

# %%
df[df["team"] == "WAS"]
df["team"]
df
# Out:
#        Unnamed: 0     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  \
# 0           16086  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0
# 1           16904  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0
# 2           16905  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0
# 3           16087  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0
# 4            1225  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0
# ...           ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 17767         973  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0
# 17768       11533  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0
# 17769       11532  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0
# 17770        7477  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0
# 17771        7476  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          43.7         206.0         104.0       GSW        111
# 1      ...          34.6         162.0         104.0       CHI         97
# 2      ...          29.0         138.0         105.0       CLE         95
# 3      ...          38.9         201.0         120.0       NOP         95
# 4      ...          23.6         132.0         104.0       DET        106
# ...    ...           ...           ...           ...       ...        ...
# 17767  ...          36.3         133.0         112.0       GSW        107
# 17768  ...          94.4         300.0         112.0       BOS         94
# 17769  ...          36.2         222.0         107.0       GSW        104
# 17770  ...          31.5         186.0         111.0       GSW        103
# 17771  ...          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False   False
# 1             1    2016  2015-10-27  False    True
# 2             0    2016  2015-10-27   True    True
# 3             0    2016  2015-10-27   True    True
# 4             0    2016  2015-10-27  False    True
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False   False
# 17768         0    2022  2022-06-13   True    True
# 17769         1    2022  2022-06-13  False   False
# 17770         0    2022  2022-06-16  False     NaN
# 17771         1    2022  2022-06-16   True     NaN
#
# [17772 rows x 149 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors = "ignore")
df
# Out:
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\3806146964.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# C:\Users\abelc\AppData\Local\Temp\ipykernel_40056\3806146964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2
#        Unnamed: 0     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  \
# 0           16086  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0
# 1           16904  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0
# 2           16905  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0
# 3           16087  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0
# 4            1225  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0
# ...           ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 17767         973  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0
# 17768       11533  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0
# 17769       11532  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0
# 17770        7477  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0
# 17771        7476  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          43.7         206.0         104.0       GSW        111
# 1      ...          34.6         162.0         104.0       CHI         97
# 2      ...          29.0         138.0         105.0       CLE         95
# 3      ...          38.9         201.0         120.0       NOP         95
# 4      ...          23.6         132.0         104.0       DET        106
# ...    ...           ...           ...           ...       ...        ...
# 17767  ...          36.3         133.0         112.0       GSW        107
# 17768  ...          94.4         300.0         112.0       BOS         94
# 17769  ...          36.2         222.0         107.0       GSW        104
# 17770  ...          31.5         186.0         111.0       GSW        103
# 17771  ...          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 149 columns]

# %%
df["won"].value_counts()
# Out:
# won
# False    8886
# True     8886
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    8872
# 0    8870
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)
nulls = nulls.sum()

nulls
# Out:
# Unnamed: 0    0
# mp            0
# fg            0
# fga           0
# fg%           0
#              ..
# home_opp      0
# season        0
# date          0
# won           0
# target        0
# Length: 149, dtype: int64

# %%
 nulls = nulls[nulls > 0]

# %%
valid_col = df.columns[~df.columns.isin(nulls.index)]
valid_col
# Out:
# Index(['Unnamed: 0', 'mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=143)

# %%
df = df[valid_col].copy()
df
# Out:
#        Unnamed: 0     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  \
# 0           16086  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0
# 1           16904  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0
# 2           16905  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0
# 3           16087  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0
# 4            1225  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0
# ...           ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 17767         973  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0
# 17768       11533  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0
# 17769       11532  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0
# 17770        7477  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0
# 17771        7476  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          43.7         206.0         104.0       GSW        111
# 1      ...          34.6         162.0         104.0       CHI         97
# 2      ...          29.0         138.0         105.0       CLE         95
# 3      ...          38.9         201.0         120.0       NOP         95
# 4      ...          23.6         132.0         104.0       DET        106
# ...    ...           ...           ...           ...       ...        ...
# 17767  ...          36.3         133.0         112.0       GSW        107
# 17768  ...          94.4         300.0         112.0       BOS         94
# 17769  ...          36.2         222.0         107.0       GSW        104
# 17770  ...          31.5         186.0         111.0       GSW        103
# 17771  ...          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 143 columns]

# %% [markdown]
# pip install sckit-learn

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\abelc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\abelc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.13.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 919.0 kB/s eta 0:00:12
#    - -------------------------------------- 0.4/11.0 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/11.0 MB 7.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.0 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.0 MB 5.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.0 MB 5.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 32.7 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    --------------------------------------- 301.8/301.8 kB 18.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\abelc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha = 1)
split = TimeSeriesSplit(n_splits = 3)
sfs = SequentialFeatureSelector(rr, n_features_to_select = 30, direction ="forward", cv= split)

# %%
removed_col = ["season", "date", "won", "target", "team", "team_opp"]
selected_col = df.columns[~df.columns.isin(removed_col)]

# %% [markdown]
# scaling part

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[selected_col] = scaler.fit_transform(df[selected_col])
df
# Out:
#        Unnamed: 0   mp        fg       fga       fg%        3p       3pa  \
# 0        0.905183  0.0  0.363636  0.338235  0.366029  0.206897  0.212121
# 1        0.951213  0.0  0.431818  0.500000  0.322967  0.310345  0.378788
# 2        0.951269  0.0  0.409091  0.397059  0.373206  0.241379  0.227273
# 3        0.905239  0.0  0.500000  0.529412  0.377990  0.310345  0.393939
# 4        0.068933  0.0  0.409091  0.323529  0.435407  0.275862  0.348485
# ...           ...  ...       ...       ...       ...       ...       ...
# 17767    0.054752  0.0  0.340909  0.367647  0.313397  0.517241  0.515152
# 17768    0.648979  0.0  0.500000  0.411765  0.471292  0.310345  0.545455
# 17769    0.648922  0.0  0.272727  0.220588  0.344498  0.379310  0.424242
# 17770    0.420742  0.0  0.340909  0.294118  0.373206  0.379310  0.363636
# 17771    0.420685  0.0  0.431818  0.470588  0.344498  0.655172  0.636364
#
#             3p%        ft       fta  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.395487  0.418605  0.412698  ...      0.277279      0.554502
# 1      0.368171  0.209302  0.253968  ...      0.160462      0.345972
# 2      0.437055  0.348837  0.349206  ...      0.088575      0.232227
# 3      0.356295  0.441860  0.333333  ...      0.215661      0.530806
# 4      0.351544  0.255814  0.222222  ...      0.019255      0.203791
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.469121  0.302326  0.285714  ...      0.182285      0.208531
# 17768  0.267221  0.279070  0.222222  ...      0.928113      1.000000
# 17769  0.408551  0.465116  0.476190  ...      0.181001      0.630332
# 17770  0.466746  0.232558  0.174603  ...      0.120668      0.459716
# 17771  0.490499  0.162791  0.111111  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 2          0.329412       CLE   0.298077       0.0    2016  2015-10-27   True
# 3          0.505882       NOP   0.298077       0.0    2016  2015-10-27   True
# 4          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# ...             ...       ...        ...       ...     ...         ...    ...
# 17767      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17768      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17769      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17770      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
# 17771      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17767       0
# 17768       1
# 17769       0
# 17770       2
# 17771       2
#
# [17772 rows x 143 columns]

# %%
sfs.fit(df[selected_col], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []

    seasons = sorted(data["season"].unique())

    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]

        model.fit(train[predictors], train["target"])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions["actual"], predictions["prediction"])

# %%
import json

# Example NBA game data
games = [
    {
        "id": 1,
        "teamA": "Los Angeles Lakers",
        "teamB": "Golden State Warriors",
        "date": "2024-09-12T19:30:00",
        "oddsA": 1.5,
        "oddsB": 2.0
    },
    {
        "id": 2,
        "teamA": "Boston Celtics",
        "teamB": "Brooklyn Nets",
        "date": "2024-09-13T20:00:00",
        "oddsA": 1.8,
        "oddsB": 1.9
    }
]

# Export the games data to a JSON file
with open('nba_games.json', 'w') as f:
    json.dump(games, f)
